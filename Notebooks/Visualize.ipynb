# %%
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np

# %%
with open('EvaluationTranformerIni.pkl', 'rb') as f:
    results = pkl.load(f)[0]

# %%
results.keys()
# Out:
# dict_keys(['AUC', 'MRR', 'NDCG5', 'NDCG10', 'loss_vali', 'Loss_training'])

# %%
Loss_training_mean = np.mean(np.array(results['Loss_training']).reshape(265,-1), axis=1)
Loss_vali = np.array(results['loss_vali'])
AUC = np.array(results['AUC'])
MRR = np.array(results['MRR'])

# %%
fig, axs = plt.subplots(2,1 ,figsize=(15,8))

axs[1].plot(np.linspace(0,50,len(Loss_training_mean)),Loss_training_mean, label = 'Training Loss',color = 'orange')
axs[0].plot(Loss_vali, label = 'Validation Loss')

axs[0].legend()
axs[1].legend()

plt.show()

# %%
np.argmax(AUC)
# Out:
# 32

# %%
max(AUC)
# Out:
# 0.625

# %%
fig, axs = plt.subplots(1,1 ,figsize=(10,6))

axs.plot(AUC, label = 'AUC')
axs.set_title('AUC')
axs.legend()

plt.show()

# %%
fig, axs = plt.subplots(1,1 ,figsize=(15,8))

axs.plot(MRR, label = 'MRR')
axs.set_title('MRR')
axs.legend()

plt.show()

# %%
with open("losses_train.pkl", 'rb') as f:
    loss = pkl.load(f)

# %%
fig, axs = plt.subplots(1,1 ,figsize=(15,8))

axs.plot(np.linspace(0,10,len(loss)),loss, label = 'Training Loss')
#axs.plot(Loss_vali, label = 'Validation Loss')
axs.set_title('Loss')

axs.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 fig, axs = plt.subplots(1,1 ,figsize=(15,8))
# ----> 3 axs.plot(np.linspace(0,10,len(loss)),loss, label = 'Training Loss')
#       4 #axs.plot(Loss_vali, label = 'Validation Loss')
#       5 axs.set_title('Loss')
#
# NameError: name 'loss' is not defined
